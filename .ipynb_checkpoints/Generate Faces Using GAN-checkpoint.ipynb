# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import os
# Out:
# WARNING:tensorflow:From C:\Users\hp\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
#Selecting the path for image directory

directory = "img_align_celeba"

#Getting all images for directory
dataset = tf.keras.preprocessing.image_dataset_from_directory(directory= directory, color_mode = 'rgb',batch_size = 128,image_size = (32,32),
                                                   label_mode = None, shuffle = True, seed = 42)
# As we know that image is basically an array consisting of elements from 0 to 255
#Normalizing the dataset by dividing it with 255 to get the image values between 0 and 1

dataset = dataset.map(lambda x:x /255.00)
# Out:
# Found 202599 files belonging to 1 classes.

# %%
# Grid of image
from mpl_toolkits.axes_grid1 import ImageGrid

# %%
iterator =iter(dataset)
one_batch = next(iterator).numpy()
images = one_batch[:16,:,:,:]

# show the image

fig = plt.figure(figsize=(5,5))
grid = ImageGrid(fig, 111, nrows_ncols=(4,4), 
         axes_pad=0)
for ax,im in zip(grid, images):
    ax.imshow(im)
plt.show()

# %%
#Creating a Discriminator

from tensorflow.keras.layers import Conv2D, LeakyReLU,BatchNormalization, Dropout, Flatten, Dense, Activation, Reshape
from tensorflow.keras import Model, Input

def discriminator():
    disc_input = Input(shape=(32,32,3), name='discriminator_network')
    x=Conv2D(filters=64, kernel_size=3, strides=(2,2), padding='same')(disc_input)
    x=LeakyReLU()(x)
    x=Dropout(0.2)(x)
    
    x=Conv2D(filters=128, kernel_size=3, strides=(2,2), padding='same')(x)
    x=LeakyReLU()(x)
    x=Dropout(0.2)(x)
    
    x=Conv2D(filters=128, kernel_size=3, strides=(2,2), padding='same')(x)
    x=LeakyReLU()(x)
    x=Dropout(0.2)(x)
    
    x=Conv2D(filters=64, kernel_size=3, strides=(2,2), padding='same')(x)
    x=LeakyReLU()(x)
    x=Dropout(0.2)(x)
    
    x=Flatten()(x)
    x=Dense(1)(x)
    
    output = Activation('sigmoid')(x)
    
    discriminator=Model(inputs = disc_input, outputs=output)
    
    return discriminator

# %%
discriminator()

# %%
disc_model = discriminator()
disc_model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\hp\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  discriminator_network (Inp  [(None, 32, 32, 3)]       0
#  utLayer)
#
#  conv2d (Conv2D)             (None, 16, 16, 64)        1792
#
#  leaky_re_lu (LeakyReLU)     (None, 16, 16, 64)        0
#
#  dropout (Dropout)           (None, 16, 16, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 128)         73856
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 8, 8, 128)         0
#
#  dropout_1 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 128)         147584
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 4, 4, 128)         0
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 64)          73792
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 2, 2, 64)          0
#
#  dropout_3 (Dropout)         (None, 2, 2, 64)          0
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 1)                 257
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 297281 (1.13 MB)
# Trainable params: 297281 (1.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Creating a Generator

from tensorflow.keras.layers import Conv2D, LeakyReLU,BatchNormalization, Dropout, Flatten, Dense, Activation, Reshape, Conv2DTranspose
from tensorflow.keras import Model, Input

def generator(z_dim=100):
    gen_input = Input(shape=(z_dim), name='generator_network')
    
    #Creating noise
    x = Dense(8*8*3)(gen_input)
    x = Reshape(target_shape=(8,8,3))(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    
    #Creating a dense Neural network
    
    x = Conv2DTranspose(filters=512, kernel_size=3, strides=(1,1), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    
    x = Conv2DTranspose(filters=256, kernel_size=3, strides=(2,2), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    
    x = Conv2DTranspose(filters=128, kernel_size=3, strides=(1,1), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    
    x = Conv2DTranspose(filters=128, kernel_size=3, strides=(2,2), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    
        
    x = Conv2DTranspose(filters=64, kernel_size=3, strides=(1,1), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    
    x = Conv2DTranspose(filters=3, kernel_size=3, strides=(1,1), padding='same')(x)
    output = LeakyReLU()(x)
    
    model_gen=Model(inputs = gen_input, outputs=output)
    
    return model_gen

# %%
generator()
# Out:
# WARNING:tensorflow:From C:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.

# %%
gen_model = generator()
gen_model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  generator_network (InputLa  [(None, 100)]             0
#  yer)
#
#  dense_3 (Dense)             (None, 192)               19392
#
#  reshape_1 (Reshape)         (None, 8, 8, 3)           0
#
#  batch_normalization_6 (Bat  (None, 8, 8, 3)           12
#  chNormalization)
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 8, 8, 3)           0
#
#  conv2d_transpose_6 (Conv2D  (None, 8, 8, 512)         14336
#  Transpose)
#
#  batch_normalization_7 (Bat  (None, 8, 8, 512)         2048
#  chNormalization)
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 8, 8, 512)         0
#
#  conv2d_transpose_7 (Conv2D  (None, 16, 16, 256)       1179904
#  Transpose)
#
#  batch_normalization_8 (Bat  (None, 16, 16, 256)       1024
#  chNormalization)
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 16, 16, 256)       0
#
#  conv2d_transpose_8 (Conv2D  (None, 16, 16, 128)       295040
#  Transpose)
#
#  batch_normalization_9 (Bat  (None, 16, 16, 128)       512
#  chNormalization)
#
#  leaky_re_lu_18 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_transpose_9 (Conv2D  (None, 32, 32, 128)       147584
#  Transpose)
#
#  batch_normalization_10 (Ba  (None, 32, 32, 128)       512
#  tchNormalization)
#
#  leaky_re_lu_19 (LeakyReLU)  (None, 32, 32, 128)       0
#
#  conv2d_transpose_10 (Conv2  (None, 32, 32, 64)        73792
#  DTranspose)
#
#  batch_normalization_11 (Ba  (None, 32, 32, 64)        256
#  tchNormalization)
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 32, 32, 64)        0
#
#  conv2d_transpose_11 (Conv2  (None, 32, 32, 3)         1731
#  DTranspose)
#
#  leaky_re_lu_21 (LeakyReLU)  (None, 32, 32, 3)         0
#
# =================================================================
# Total params: 1736143 (6.62 MB)
# Trainable params: 1733961 (6.61 MB)
# Non-trainable params: 2182 (8.52 KB)
# _________________________________________________________________

# %%
disc_model = discriminator()
gen_model = generator()
# Image Classification CNN
# Compile the model that trains disc.
disc_model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\hp\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# Compile the model that trains generator
z_dim = 100
disc_model.trainable = False
model_input = Input(shape=(z_dim), name='model_input')
model_output = disc_model(gen_model(model_input))

model = Model(model_input, model_output)

model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  model_input (InputLayer)    [(None, 100)]             0
#
#  model_5 (Functional)        (None, 32, 32, 3)         1736143
#
#  model_4 (Functional)        (None, 1)                 297281
#
# =================================================================
# Total params: 2033424 (7.76 MB)
# Trainable params: 1733961 (6.61 MB)
# Non-trainable params: 299463 (1.14 MB)
# _________________________________________________________________

# %%
def train_discriminator(batch, batch_size):
    valid = np.ones((batch_size, 1)) 
    fake = np.zeros((batch_size, 1)) 
    
    disc_model.train_on_batch(batch, valid)
    
    noise = np.random.normal(0,1, (batch_size, z_dim))
    gen_image = gen_model.predict(noise)
    disc_model.train_on_batch(gen_image, fake)
    
def train_generator(batch_size):
    valid = np.ones((batch_size, 1)) 
    noise = np.random.normal(0,1, (batch_size, z_dim))
    model.train_on_batch(noise, valid)

# %%
def save_image(fake_image, path):
    image = tf.keras.preprocessing.image.array_to_img(fake_image.numpy())
    tf.keras.preprocessing.image.save_img(path, image)
    return image
def generate_and_save_image(path):
    noise = np.random.normal(0,1, (1, z_dim))
    fake_images = gen_model(noise)
    image = save_image(fake_images[0], path)
    plt.imshow(image)
    plt.show()

# %% [markdown]
# Try to Train it on GPU otherwise the Notebook will be crashed

# %%
for epochs in range(10):
    print(f'No of Epochs-> {epochs}')
    for i,batch in enumerate(dataset):
        train_discriminator(batch, batch.shape[0])
        train_generator(batch.shape[0])
        if i%100==0:
            print(f'Batch Images-> {i}')
            PATH = 'generate_face'
            generate_and_save_image(path = f'{PATH}/epochs_{epochs}batch_{i}.jpg')
# Out:
# No of Epochs-> 0
# WARNING:tensorflow:From C:\Users\hp\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\hp\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 4/4 [==============================] - 1s 188ms/step
# Batch Images-> 0
# 4/4 [==============================] - 1s 179ms/step
# 4/4 [==============================] - 1s 204ms/step
# 4/4 [==============================] - 1s 241ms/step
# 4/4 [==============================] - 1s 177ms/step
# 4/4 [==============================] - 1s 281ms/step
# 4/4 [==============================] - 1s 199ms/step
# 4/4 [==============================] - 1s 170ms/step
# 4/4 [==============================] - 1s 197ms/step
# 4/4 [==============================] - 1s 169ms/step
# 4/4 [==============================] - 1s 212ms/step
# 4/4 [==============================] - 1s 238ms/step
# 4/4 [==============================] - 1s 164ms/step
# 4/4 [==============================] - 1s 204ms/step
# 4/4 [==============================] - 1s 188ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 5
#       3 for i,batch in enumerate(dataset):
#       4     train_discriminator(batch, batch.shape[0])
# ----> 5     train_generator(batch.shape[0])
#       6     if i%100==0:
#       7         print(f'Batch Images-> {i}')
#
# Cell In[18], line 14, in train_generator(batch_size)
#      12 valid = np.ones((batch_size, 1))
#      13 noise = np.random.normal(0,1, (batch_size, z_dim))
# ---> 14 model.train_on_batch(noise, valid)
#
# File ~\anaconda3\Lib\site-packages\keras\src\engine\training.py:2779, in Model.train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics, return_dict)
#    2777 _disallow_inside_tf_function("train_on_batch")
#    2778 if reset_metrics:
# -> 2779     self.reset_metrics()
#    2780 with self.distribute_strategy.scope(), training_utils.RespectCompiledTrainableState(  # noqa: E501
#    2781     self
#    2782 ):
#    2783     iterator = data_adapter.single_batch_iterator(
#    2784         self.distribute_strategy, x, y, sample_weight, class_weight
#    2785     )
#
# File ~\anaconda3\Lib\site-packages\keras\src\engine\training.py:2723, in Model.reset_metrics(self)
#    2704 """Resets the state of all the metrics in the model.
#    2705
#    2706 Examples:
#    (...)
#    2720
#    2721 """
#    2722 for m in self.metrics:
# -> 2723     m.reset_state()
#
# File ~\anaconda3\Lib\site-packages\keras\src\metrics\base_metric.py:265, in Metric.reset_state(self)
#     263     return self.reset_states()
#     264 else:
# --> 265     backend.batch_set_value([(v, 0) for v in self.variables])
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\util\dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\anaconda3\Lib\site-packages\keras\src\backend.py:4311, in batch_set_value(tuples)
#    4309     for x, value in tuples:
#    4310         value = np.asarray(value, dtype=dtype_numpy(x))
# -> 4311         _assign_value_to_variable(x, value)
#    4312 else:
#    4313     with get_graph().as_default():
#
# File ~\anaconda3\Lib\site-packages\keras\src\backend.py:4359, in _assign_value_to_variable(variable, value)
#    4356     variable.assign(d_value)
#    4357 else:
#    4358     # For the normal tf.Variable assign
# -> 4359     variable.assign(value)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py:142, in weak_tensor_binary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#     140 def wrapper(*args, **kwargs):
#     141   if not ops.is_auto_dtype_conversion_enabled():
# --> 142     return op(*args, **kwargs)
#     143   bound_arguments = signature.bind(*args, **kwargs)
#     144   bound_arguments.apply_defaults()
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1056, in BaseResourceVariable.assign(self, value, use_locking, name, read_value)
#    1054   validate_shape = self._validate_shape and self._shape.is_fully_defined()
#    1055   kwargs["validate_shape"] = validate_shape
# -> 1056 assign_op = gen_resource_variable_ops.assign_variable_op(
#    1057     self.handle, value_tensor, name=name, **kwargs)
#    1058 if read_value:
#    1059   return self._lazy_read(assign_op)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py:149, in assign_variable_op(resource, value, validate_shape, name)
#     147 if tld.is_eager:
#     148   try:
# --> 149     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     150       _ctx, "AssignVariableOp", name, resource, value, "validate_shape",
#     151       validate_shape)
#     152     return _result
#     153   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
